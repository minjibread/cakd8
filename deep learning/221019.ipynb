# %% [markdown]
# # 복습문제

# %% [markdown]
# ----------

# %% [markdown]
# > IQR의 범위는?

# %% [markdown]
# 4/3 - 1/4

# %% [markdown]
# ------------

# %% [markdown]
# > 이상치의 범위는?

# %% [markdown]
# pct25 = min - 1.5 * IQR
# pct75 = max +  1.5 * IQR

# %% [markdown]
# ---------------

# %% [markdown]
# > 다수의 약한 학습기를 결합해 변동성을 줄여 예측오류를 줄이고 성능을 개선한 기법은?

# %% [markdown]
# 앙상블(Ensemble)? Boosting?

# %% [markdown]
# -----------

# %% [markdown]
# > 언더샘플링과 오버샘플링은 무엇인가?

# %% [markdown]
# 언더샘플링 : 많은 데이터를 적은 데이터 수준으로 감소시키는 방식<br>
# 오버샘플링 : 적은 데이터를 많은 데이터 수준으로 증식하여 학습을 위한 충분한 데이터 세트를 확보하는 방식

# %% [markdown]
# --------------

# %% [markdown]
# > 여러 알고리즘을 사용하여 예측 결과를 만들고 그 예측 결과들을 모아 다시 학습하여 최종 예측 결과물을 도출하는 앙상블 기법은?

# %% [markdown]
# Stacking

# %% [markdown]
# -----------

# %% [markdown]
# SMOTE 기법은 정밀도 지표보다 재현율 지표를 높일 때 더 효과적이다? O/X

# %% [markdown]
# O

# %% [markdown]
# -----------------

# %% [markdown]
# > mpg 데이터에서 fl이 r, p인 것들만 추출해 주세요.

# %%
import pydataset

mpg = pydataset.data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
a = ['e', 'd', 'c']

mpg = mpg[~mpg['fl'].isin(a)]

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.query("fl == 'r' or fl == 'p'")
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# -------------

# %% [markdown]
# > 'cty'를 표준화해 봅시다.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit_transform(mpg['cty'].values.reshape(-1,1))
# Out:
# array([[ 0.30096486],
#        [ 1.11172734],
#        [ 0.84147318],
#        [ 1.11172734],
#        [-0.23954346],
#        [ 0.30096486],
#        [ 0.30096486],
#        [ 0.30096486],
#        [-0.23954346],
#        [ 0.84147318],
#        [ 0.57121902],
#        [-0.50979762],
#        [ 0.0307107 ],
#        [ 0.0307107 ],
#        [-0.50979762],
#        [-0.50979762],
#        [ 0.0307107 ],
#        [-0.23954346],
#        [-0.78005178],
#        [-0.78005178],
#        [-1.05030594],
#        [-1.3205601 ],
#        [-0.23954346],
#        [-0.50979762],
#        [-0.23954346],
#        [-0.50979762],
#        [-0.50979762],
#        [-0.78005178],
#        [-1.59081426],
#        [ 0.57121902],
#        [ 1.3819815 ],
#        [ 0.30096486],
#        [ 0.30096486],
#        [ 0.0307107 ],
#        [ 0.30096486],
#        [ 0.0307107 ],
#        [-0.23954346],
#        [-0.23954346],
#        [ 0.0307107 ],
#        [ 0.0307107 ],
#        [-0.50979762],
# ...

# %%
# scaler.fit_transform(mpg[['cty']].values)으로 하면 reshape 안 해도 됨

# %%
mpg[['cty']].values.shape
# Out:
# (220, 1)

# %% [markdown]
# ------------
