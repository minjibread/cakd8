# %% [markdown]
# # 복습문제

# %%
다음 빈칸에 알맞은 라이브러리명을 적으세요.

1. (    )는 HTTP 요청을 보낼 수 있도록 기능을 제공하는 라이브러리이다.

import requests, from urllib import request

2. (    )은 웹 페이지의 정보를 쉽게 스크랩할 수 있도록 기능을 제공하는 라이브러리이다.

BeautifulSoup

3. (   )은 동적으로 변하는 웹 페이지의 데이터들까지 설정하여 크롤링할 수 있다.

webdriver

# %%
URL 처리 시 한글이 포함되어 있는 경우, 한글이 잘 인식하도록 해 주는 함수는 무엇인가?

quote_plus

# %%
다음은 웹에서 이미지를 검색해 폴더에 저장하는 콛 중 일부를 순서에 상관없이 나열한 것이다. 순서대로 서술하시오.

ㄱ. driver.get(url)
ㄴ. driver = webdriver.Chrome('./chromedriver.exe')
ㄷ. time.sleep(5)
ㄹ. html = driver.page_source
ㅁ. soup = BeautifulSoup(html, 'html.parser')

ㄴ-ㄱ-ㄷ-ㄹ-ㅁ

# %%
로봇으로 요청을 했을 경우, 정보를 주지 않는 곳도 있다. 웹브라우저 정보를 header에 담아보낸다. 정보는 { "       "  :               }

User-Agent

# %%
request.urlopen(url).read()
requests.get(url).text

html : hypretext markup language

# %%
HTML에서 페이지 이동 시 url(또는 uri)에 데이터를 포함하여 전달해서 쓰는 방식을 (    ) 라고 한다.

get

# %%
soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

# %%
find_all 대신 (    ) 을 사용할 수 있다.

soup. (1) ( (2)  )

(1) select
(2) class_ 해당하는 문장? 단어?

# %%
# 아래 주소에서 역대 대통령의 이름들을 추출해 주세요.

# https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D'

# %%
header = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
html = requests.get(url, headers = header).text

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>대한민국의 대통령 목록 - 위키백과, 우리 모두의 백과사전</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"],"wgRequestId":"c8c45647-d6c8-4b17-b85b-ffc38642de13","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"대한민국의_대통령_목록","wgTitle":"대한민국의 대통령 목록","wgCurRevisionId":33430829,"wgRevisionId":33430829,"wgArticleId":319386,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["타임라인을 사용하는 문서","위키데이터 속성 P373을 사용하는 문서","준보호 문서","대한민국의 대통령","대한민국 정치에 관한 목록","대통령 목록","대한민국 사람 목록"],"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext",
# ...

# %% [markdown]
# --------

# %%
table = soup.find(class_ = 'wikitable').find_all('b')
name = [i.find('a') for i in table]
name = list(filter(None, name))
[i.text for i in name]
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %% [markdown]
# ----------

# %%
all_text = soup.select('td > b > a')

for a in all_text:
    print(a.text)
# Out:
# 이승만
# 윤보선
# 박정희
# 최규하
# 전두환
# 노태우
# 김영삼
# 김대중
# 노무현
# 이명박
# 박근혜
# 문재인
# 윤석열

# %% [markdown]
# -------------

# %%
names = soup.select('td:nth-child(3) > b > a')
pre_names = [name.attrs['title'] for name in names]
pre_names
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %% [markdown]
# -------
