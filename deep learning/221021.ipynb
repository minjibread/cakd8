# %% [markdown]
# # 복습문제

# %% [markdown]
# Q. 분포가 심하게 왜곡되었을 경우 ( )변환을 적용하는 것이 좋다. ( )에 들어갈 말은?

# %% [markdown]
# 로그

# %% [markdown]
# Q. 로지스틱 회귀는 분류 알고리즘이다? O/X

# %% [markdown]
# O

# %% [markdown]
# 승산비 = odds ratio = 오즈비 = $\frac {p}{1-p}$ = $\frac{성공확률}{실패확률}$

# %% [markdown]
# Q. 주성분을 가진 데이터 세트로 차원 축소를 하는 것은?

# %% [markdown]
# PCA

# %% [markdown]
# - 데이터 변동성이 가장 ( 큰 ) 방향으로 축을 생성함

# %% [markdown]
# Q. 차원 축소법은 크게 '피처 선택'과 '피처 추출'로 나눌 수 있다. '피처 선택'이란?

# %% [markdown]
# 주요 피처만 선택

# %% [markdown]
# Q. 로그 변환을 할 때 그 함수는 ( ) 로 수행한다. ( )에 들어갈 말은?

# %% [markdown]
# np.log1p()

# %% [markdown]
# Q. 다시 지수로 변환하는 함수는?

# %% [markdown]
# np.expm1()

# %% [markdown]
# Q. 차원 축소를 진행한 이후 원래 자료로 완벽하게 복구할 수 있나요? o/x

# %% [markdown]
# x

# %% [markdown]
# Q. LinearRegression: X에 대한 결과값은 int, float, 연속된 숫자형
#    LogisticRegression : X에 대한 결과값은 범주형

# %% [markdown]
# Q. 회귀 트리 Regressor 클래스는 coef_ 속성이 없고 대신 feature_importances_를 이용해 피처별 중요도를 알 수 있다? o/x

# %% [markdown]
# o

# %% [markdown]
# Q. 로지스팁 회귀는 0~1 사이에서 완만한 s자 커브를 그린다. 이 곡선의 이름은?

# %% [markdown]
# 시그모이드 함수

# %% [markdown]
# Q. 머신러닝에서 결과에 대한 예측 확률을 높이기 위해 전처리 작업을 시도하려고 합니다. 시도해 볼 수 있는 전처리 작업들을 적어주세요.

# %% [markdown]
# 결측치 대체, 이상치 제거, 레이블 인코딩, 원-핫 인코딩, 정규화, 표준화, 로그 변환, 차원 축소 등

# %% [markdown]
# Q. LogisticRegression 클래스의 하이퍼 파ㅏ미터 중 'C'값이 작을수록 규제 강도가 크다? o/x

# %% [markdown]
# o

# %% [markdown]
# Q. PCA(n_components = )에서 n_components의 역할은?

# %% [markdown]
# 변환할 차원의 개수

# %%
import pydataset
mpg = pydataset.data('mpg')

# %%
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %% [markdown]
# Q. manufacturer는 모두 몇 개 회사입니까?

# %%
mpg['manufacturer'].value_counts().shape
# Out:
# (15,)

# %%
# len(mpg.manufacturer.unique()))

# %%
import seaborn as sns

top5 = mpg['manufacturer'].value_counts()[:5]
top5
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# Name: manufacturer, dtype: int64

# %%
sns.barplot(x = top5.values, y = top5.index)
# Out:
# <AxesSubplot:>

# %% [markdown]
# --------------------

# %%
# 5개 회사만 있는 df : 행추출

# %%
a=['dodge','toyota','volkswagen','ford','chevrolet']
mpg[mpg['manufacturer'].isin(a)]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# ...

# %%
a=['dodge','toyota','volkswagen','ford','chevrolet']
df2=mpg[mpg['manufacturer'].isin(a)]
df2=df2.reset_index(drop=True)
df2
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0      chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 1      chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 2      chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 3      chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 4      chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 5      chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 6      chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 7      chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 8      chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 9      chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 10     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# ...

# %%
mpg.query("manufacturer in ['dodge','toyota','volkswagen','ford','chevrolet']")
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# ...
